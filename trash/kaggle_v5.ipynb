# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import csv
import datetime
import math

# %% [markdown]
# # myLibrary

# %%
#製造answer.csv的第1列
def answer_header():
    header = ['user_id']
    for i in range(28):
        header.append('time_slot_' + str(i) )
    return header

# %% [markdown]
# # Main

# %%
answer_v2 = pd.read_csv('answer_v2.csv')
reference = pd.read_csv('reference.csv')
threshold = 12
with open('answer_v5.csv', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(answer_header())
    
    for i in range(len(answer_v2)):
        id = int(answer_v2.values[i][0])
        print(id)
        v2_list = answer_v2.values[i][1:]
        found = False
        for j in range(len(reference_sum)):
            target_id = int(reference.values[j][0])
            target_list = reference.values[0][1:]
            
            if np.sum(np.absolute(v2_list - target_list)) < threshold:
                found = True
                print(target_id)
                for label_count in range(1,46):
                    label_data = pd.read_csv('public/label-0' + str(label_count) + '.csv')

                    # 取得目前csv檔案的首尾user_id
                    head = label_data.head(1)['user_id'].values[0]
                    tail = label_data.tail(1)['user_id'].values[0]
                    if head <= target_id and target_id <= tail:
                        target = label_data
                        break
                
                writer.writerow([id] + list(label_data[label_data['user_id'] == target_id].values[0][1:]))
                break
        if not found:
            writer.writerow([id] + [0.5]*28)
        break
# Out:
# 57159

# %% [markdown]
# # Check file

# %%
reference = pd.read_csv('reference.csv')
reference_sum = pd.read_csv('reference_sum.csv')
answer_v2 = pd.read_csv('answer_v2.csv')
answer_v2_sum = pd.read_csv('answer_v2_sum.csv')
answer_v5 = pd.read_csv('answer_v5.csv')
answer_v5
# Out:
#    user_id  time_slot_0  time_slot_1  time_slot_2  time_slot_3  time_slot_4  \
# 0    57159          0.5          0.5          0.5          0.5          0.5
#
#    time_slot_5  time_slot_6  time_slot_7  time_slot_8      ...       \
# 0          0.5          0.5          0.5          0.5      ...
#
#    time_slot_18  time_slot_19  time_slot_20  time_slot_21  time_slot_22  \
# 0           0.5           0.5           0.5           0.5           0.5
#
#    time_slot_23  time_slot_24  time_slot_25  time_slot_26  time_slot_27
# 0           0.5           0.5           0.5           0.5           0.5
#
# [1 rows x 29 columns]

# %%
answer_v2
# Out:
#        user_id   time_slot_0   time_slot_1  time_slot_2   time_slot_3  \
# 0        57159  8.435059e-01  8.431549e-01     0.085327  1.511230e-01
# 1        57160  1.562500e-02  7.656250e-01     0.015625  0.000000e+00
# 2        57161  0.000000e+00  0.000000e+00     0.000000  0.000000e+00
# 3        57162  0.000000e+00  0.000000e+00     0.000000  0.000000e+00
# 4        57163  2.500000e-01  2.500000e-01     0.000000  0.000000e+00
# 5        57164  0.000000e+00  0.000000e+00     0.000000  0.000000e+00
# 6        57165  5.000000e-01  5.810547e-01     0.125977  1.953125e-03
# 7        57166  0.000000e+00  7.500000e-01     0.000000  0.000000e+00
# 8        57167  5.165340e-01  8.944780e-01     0.014687  0.000000e+00
# 9        57168  8.631876e-01  9.916055e-01     0.000000  9.611805e-01
# 10       57169  8.281250e-01  9.443359e-01     0.312500  1.125000e+00
# 11       57170  7.301569e-07  4.768372e-07     0.000000  0.000000e+00
# ...

# %%
answer_v2_sum
# Out:
#           id        sum
# 0      57159  13.758451
# 1      57160   4.205566
# 2      57161   0.500000
# 3      57162   3.311523
# 4      57163   1.250000
# 5      57164   0.500000
# 6      57165   5.838379
# 7      57166   4.000007
# 8      57167  11.101135
# 9      57168  15.292698
# 10     57169  19.550781
# 11     57170   0.500003
# 12     57171  13.321777
# 13     57172   2.131470
# 14     57173   5.114269
# 15     57174   5.529450
# 16     57175   0.125000
# 17     57176   1.531312
# 18     57177   3.613638
# 19     57178  10.855225
# 20     57179  10.250000
# 21     57180   0.875000
# 22     57181   1.139915
# 23     57182   1.291512
# 24     57183   0.599609
# 25     57184   2.357422
# 26     57185   5.038086
# 27     57186   9.807594
# 28     57187   6.796875
# 29     57188   0.382839
# ...      ...        ...
# 37062  94221   5.376397
# 37063  94222   4.625000
# 37064  94223  10.360352
# 37065  94224   0.250153
# 37066  94225   0.500000
# 37067  94226   0.031250
# ...

# %%
reference
# Out:
#        user_id   time_slot_0   time_slot_1   time_slot_2   time_slot_3  \
# 0            0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 1            1  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 2            2  0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 3            3  0.000000e+00  4.882812e-04  0.000000e+00  0.000000e+00
# 4            4  4.687500e-01  9.687500e-01  0.000000e+00  8.125000e-01
# 5            5  0.000000e+00  5.000000e-01  0.000000e+00  0.000000e+00
# 6            6  5.187988e-04  6.913698e-01  4.882812e-04  6.122589e-04
# 7            7  6.250000e-01  5.625000e-01  5.625000e-01  0.000000e+00
# 8            8  1.007082e-03  1.983643e-03  0.000000e+00  0.000000e+00
# 9            9  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 10          10  4.882812e-04  0.000000e+00  4.882812e-04  0.000000e+00
# 11          11  3.969128e-01  9.110107e-01  1.250114e-01  1.406250e-01
# ...

# %%
reference_sum # .sort_values("sum").values[19][0]
# Out:
#           id           sum
# 0          0  1.074219e-02
# 1          1  5.000000e-01
# 2          2  1.250000e+00
# 3          3  5.006836e+00
# 4          4  1.690625e+01
# 5          5  7.500000e-01
# 6          6  7.879837e+00
# 7          7  1.342970e+01
# 8          8  3.143625e-03
# 9          9  5.000000e-01
# 10        10  4.394531e-03
# 11        11  1.185871e+01
# 12        12  6.984919e-10
# 13        13  9.867653e+00
# 14        14  5.468750e-02
# 15        15  1.500000e+00
# 16        16  1.464848e-02
# 17        17  5.000305e-01
# 18        18  1.619567e+01
# 19        19  4.750000e+00
# 20        20  5.095825e-01
# 21        21  1.109424e+01
# 22        22  6.250000e-01
# 23        23  5.875000e+00
# 24        24  1.957417e-03
# 25        25  2.520142e-01
# 26        26  1.252178e+01
# 27        27  3.186791e+00
# 28        28  5.000000e-01
# 29        29  4.064196e-02
# ...      ...           ...
# 57129  57129  2.000000e+00
# 57130  57130  2.765625e+00
# ...
